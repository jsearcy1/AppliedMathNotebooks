# %% [markdown]
# ## Perceptron learning
#
# In the first part of this exercise we will reproduce the Figures in Chapter 39 of the MacKay book.
#
# $x$ is an $p \times N$ matrix containing all the N-dimensional input vectors for each of the p patterns. We set $N=2$ and use an explicit threshold b in the perceptron activation; w[0] and w[1] are the weights.
#
# $z$ is a vector of length p containing the targets for each training pattern, each target $\in$ {0,1}. In class we used the notation: $z^\mu$ and $x^\mu_i$.
#
# We can choose two options: linearly separable patterns, or nonseparable patterns

# %%
import numpy as np
from matplotlib import pyplot as plt
np.random.seed(1)

# %% [markdown]
# ## Generate training set

# %%
def generate_patterns(spread,N=2,p1=100,p2=100,option='separable',plot=False):
    # spread parameter is the standard deviation of the the patterns around each center of the gaussian distribution
    # generate targets
    
    z=np.ones((p1+p2))# targets
    z[p1:]=0 # t2=0 targets
    x=np.zeros((p1+p2,N))
    
    # generate inputs
    if option=='separable':
        # separable targets
        x[0:p1,0:N]=1+spread*np.random.randn(N*p1).reshape(p1,N)
        x[p1:p1+p2,0:N]=-1+spread*np.random.randn(N*p2).reshape(p2,N)
    elif option=='nonseparable':
        x[0:p1,0:N]=1+spread*np.random.randn(N*p1).reshape(p1,N)
        x[0:int(p1/2),0:N]=-x[0:int(p1/2),0:N]
        x[p1:p1+p2,0:N]=-1+spread*np.random.randn(N*p2).reshape(p2,N)
        x[int(p1+p2/2):(p1+p2),0]=-x[int(p1+p2/2):(p1+p2),0]; x[p1:int(p1+p2/2),1]=-x[p1:int(p1+p2/2),1]
    elif option=='weird':
        x[0:p1,0:N]=1+spread*np.random.randn(N*p1).reshape(p1,N)
        x[0:int(p1/2),0:N]=-x[0:int(p1/2),0:N]+1.5
        x[p1:p1+p2,0:N]=-1+spread*np.random.randn(N*p2).reshape(p2,N)
        x[int(p1+p2/2):(p1+p2),0]=-x[int(p1+p2/2):(p1+p2),0]; x[p1:int(p1+p2/2),1]=-x[p1:int(p1+p2/2),1]+1
        z=np.ones((p1+p2))# targets
        z[0:int(p1/2)]=0; z[p1:int(p1+p2/2)]=0

    # make a figure
    if plot == True:
        fig,ax=plt.subplots()
        plt.title('Linearly {} Patterns with Spread of {}'.format(option,spread))
        size=100
        # scatterplot
        ax.scatter(x[z==1,0],x[z==1,1],s=size,color='red',alpha=0.25,label='+1')
        ax.scatter(x[z==0,0],x[z==0,1],s=size,color='blue',alpha=0.25,label='0')
        ax.set_xlabel("x1"); ax.set_ylabel("x2")
        ax.legend(loc='lower right')
        ax.axis('equal')  
    return x,z

# %%
p1=500  # size of class 0
p2=500 # size of class 1
N=2 # dimension of input space
spread=1 # within-class spread of data
# training set
x,z=generate_patterns(spread=spread,N=N,p1=p1,p2=p2,option='separable',plot=True)
print(np.shape(x))
print(np.shape(z))
print(x[p1:p1+3,:])
print(z[p1:p1+3])
# test set
x_test,z_test=generate_patterns(spread=spread,N=N,p1=100,p2=100,option='separable',plot=True)
# Out:
# (1000, 2)
# (1000,)
# [[-0.99077665 -0.04112097]
#  [-0.83509281 -1.23969001]
#  [-1.61201378 -1.01585326]]
# [0. 0. 0.]

# %% [markdown]
# ## Activity rule and cost function
#
# Activation
# $$
# h^\mu=\sum_{i=1}^Nw_i x_i^\mu+b
# $$
#
# Activity:
# $$
# f(h)={1\over 1+e^{-h}}
# $$
#
# Log-likelihood function:
# $$
# G(z^\mu|x^\mu_i,w_i)=-\sum_{\mu=1}^p\left[z^\mu\ln f(h^\mu)+(1-z^\mu)\ln(1- f(h^\mu))\right]\ , \,\,h^\mu=\sum_{i=1}^Nw_ix_i^\mu+b
# $$
#
# Log-posterior:
# $$
# M(w_i|z^\mu,x^\mu_i)=G(z^\mu|x^\mu_i,w_i)+{1\over2}\alpha \sum_{i=1}^Nw_i^2
# $$

# %%
# activity rule
b=-1; # threshold (we called it w0 in class)
def sigmoid(h0,b,derivative=False):
    # h0=sum_i w_i x_i
    h=h0+b # activation
    out=1/(1+np.exp(-h))
    return out*(1-out) if derivative else out

def Gfunc(ww,xx,zz):
    # relative entropy between target labels and input patterns
    hh0=xx.dot(ww) # xx has dim (p,N) and ww has dim (N,) --> hh0 is a row vector of dim p
    ff=sigmoid(hh0,b)
    infhh=~np.isinf(np.log(ff))
    infhhm=~np.isinf(np.log(1-ff))
    out=-zz[infhh].dot(np.log(ff[infhh]))-(1-zz[infhhm]).dot(np.log(1-ff[infhhm]))
    return out

# %% [markdown]
# ## Batch training using the perceptron learning rule
# $$
# w_i^{new}=w_i^{old}+\Delta w_i
# $$
#
# $$
# \Delta w_i=\eta\sum_{\mu=1}^p\left[\left(z^\mu-f(h^\mu)\right]x_i^\mu-\alpha w_i\right)
# $$

# %%
T=10000 # number of training steps
# snapshot of learning
stepPlot=T/1000

N=2
# initialize the weights
# w0=(1/N**0.5)*np.random.randn(N)
w0=10*np.random.randn(N)
print('initial weights %s' % w0)

# learning rate
eta=0.0001
# weight decay
alpha=0.2

# training 
EarlyStopping=True # callback to implement early stopping
Gplot=[]; Mplot=[]; wplot=[]; yplot=[]; errorTrain=[];errorTest=[]
Patience=5000 # how many steps for the EarlyStopping callback
for step in range(T):
          if step==0: w=w0
          h=x.dot(w) # vector of dim p=p1+p2
          f=sigmoid(h,b) # vector of dim p
          err=z-f # vector of dim p
          gr=-err.dot(x) # vector of dim N
          w=w-eta*(gr+alpha*w)
          if step % stepPlot==0:
                  gtemp=Gfunc(w,x,z)
                  Gplot.append(gtemp) # store the log-likelihood
                  Mplot.append(gtemp+0.5*alpha*w.dot(w)) # store the log-posterior
                  wplot.append(w)
                  yplot.append(f)
                  errorfracTrain=sum(abs(np.round(f-z)))/len(z) # fraction of training patterns that have been misclassified
                  errorTrain.append(errorfracTrain)
                  # evaluating performance on test set
                  f_test=sigmoid(x_test.dot(w),b) # perceptron output evaluated on the test set with weights learned on the training set
                  errorfracTest=sum(abs(np.round(f_test-z_test)))/len(z_test) # fraction of training patterns that have been misclassified
                  errorTest.append(errorfracTest)
                  stepErrorMin=np.argmin(errorTest)
                  if step>2*stepPlot:
                          if EarlyStopping:
                                #   if errorfracTest==0: break # stop training if error on test set is zero
                                #   if errorfracTest[-2]==errorfracTest[-1]: break # stop training if error on test set is zero
                                  if (step-stepErrorMin*stepPlot)>Patience: break # stop training if error on test set is zero

          if step % (stepPlot*10)==0:
                print('{a1} steps, G: {a2:.6e}, M: {a5:.6e}, errorTrain: {a6},errorTest: {a7}, weights: {a3:.4},{a4:.4}'.format(a1=step+1,a2=gtemp,a3=w[0],a4=w[1],a5=gtemp+0.5*alpha*w.dot(w),a6=errorfracTrain,a7=errorfracTest))

# fraction of misclassified input patterns at the end of training
print('last step %s' % step)
print('step with min error {a1}'.format(a1=(stepErrorMin)*stepPlot))
print('fraction misclassified (Train): %s' % errorTrain[stepErrorMin])
print('fraction misclassified (Test): %s' % errorTest[stepErrorMin])
print('weights at stepErrorMin: %s' % wplot[stepErrorMin])
# Out:
# initial weights [-8.79510342 -3.92997192]
# 1 steps, G: 1.258341e+04, M: 1.259244e+04, errorTrain: 0.903,errorTest: 0.92, weights: -8.693,-3.834
# 101 steps, G: 4.932258e+02, M: 4.936605e+02, errorTrain: 0.229,errorTest: 0.23, weights: -0.3296,2.059
# 201 steps, G: 2.655106e+02, M: 2.660686e+02, errorTrain: 0.119,errorTest: 0.095, weights: 1.052,2.115
# 301 steps, G: 2.446111e+02, M: 2.452852e+02, errorTrain: 0.104,errorTest: 0.09, weights: 1.496,2.122
# 401 steps, G: 2.395991e+02, M: 2.403556e+02, errorTrain: 0.103,errorTest: 0.09, weights: 1.713,2.152
# 501 steps, G: 2.378548e+02, M: 2.386708e+02, errorTrain: 0.102,errorTest: 0.09, weights: 1.836,2.188
# 601 steps, G: 2.370983e+02, M: 2.379582e+02, errorTrain: 0.102,errorTest: 0.085, weights: 1.913,2.223
# 701 steps, G: 2.367203e+02, M: 2.376131e+02, errorTrain: 0.102,errorTest: 0.085, weights: 1.963,2.253
# 801 steps, G: 2.365132e+02, M: 2.374310e+02, errorTrain: 0.102,errorTest: 0.085, weights: 1.997,2.278
# 901 steps, G: 2.363927e+02, M: 2.373297e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.021,2.298
# 1001 steps, G: 2.363196e+02, M: 2.372713e+02, errorTrain: 0.101,errorTest: 0.085, weights: 2.039,2.315
# 1101 steps, G: 2.362739e+02, M: 2.372370e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.052,2.328
# 1201 steps, G: 2.362446e+02, M: 2.372166e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.062,2.339
# 1301 steps, G: 2.362253e+02, M: 2.372042e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.069,2.347
# 1401 steps, G: 2.362125e+02, M: 2.371968e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.074,2.354
# 1501 steps, G: 2.362037e+02, M: 2.371922e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.079,2.359
# 1601 steps, G: 2.361976e+02, M: 2.371894e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.082,2.363
# 1701 steps, G: 2.361933e+02, M: 2.371877e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.085,2.366
# 1801 steps, G: 2.361902e+02, M: 2.371867e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.087,2.369
# 1901 steps, G: 2.361880e+02, M: 2.371861e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.088,2.371
# 2001 steps, G: 2.361863e+02, M: 2.371857e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.089,2.372
# 2101 steps, G: 2.361851e+02, M: 2.371854e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.09,2.373
# 2201 steps, G: 2.361842e+02, M: 2.371853e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.091,2.374
# 2301 steps, G: 2.361835e+02, M: 2.371852e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.092,2.375
# 2401 steps, G: 2.361829e+02, M: 2.371851e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.092,2.376
# 2501 steps, G: 2.361825e+02, M: 2.371851e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.093,2.376
# 2601 steps, G: 2.361822e+02, M: 2.371851e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.093,2.377
# 2701 steps, G: 2.361820e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.093,2.377
# 2801 steps, G: 2.361818e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.093,2.377
# 2901 steps, G: 2.361816e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.093,2.377
# 3001 steps, G: 2.361815e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.377
# 3101 steps, G: 2.361814e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 3201 steps, G: 2.361813e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 3301 steps, G: 2.361813e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 3401 steps, G: 2.361812e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 3501 steps, G: 2.361812e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 3601 steps, G: 2.361812e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 3701 steps, G: 2.361812e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 3801 steps, G: 2.361811e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 3901 steps, G: 2.361811e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 4001 steps, G: 2.361811e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 4101 steps, G: 2.361811e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 4201 steps, G: 2.361811e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 4301 steps, G: 2.361811e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 4401 steps, G: 2.361811e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 4501 steps, G: 2.361811e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 4601 steps, G: 2.361811e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 4701 steps, G: 2.361811e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 4801 steps, G: 2.361811e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 4901 steps, G: 2.361811e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 5001 steps, G: 2.361811e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 5101 steps, G: 2.361811e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 5201 steps, G: 2.361811e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 5301 steps, G: 2.361811e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 5401 steps, G: 2.361811e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# 5501 steps, G: 2.361811e+02, M: 2.371850e+02, errorTrain: 0.102,errorTest: 0.085, weights: 2.094,2.378
# last step 5530
# step with min error 520.0
# fraction misclassified (Train): 0.102
# fraction misclassified (Test): 0.085
# weights at stepErrorMin: [1.85462295 2.19521624]
# <ipython-input-136-c019f941e604>:14: RuntimeWarning: divide by zero encountered in log
#   infhhm=~np.isinf(np.log(1-ff))

# %% [markdown]
# ## Plot learning schedule
#
# Plot classification probability $P=0.25,0.75$ using the activity rule (P is the output of the perceptron): $h=\log[P/(1-P)]$

# %%
# plot evolution of the weights
fig,ax=plt.subplots(1,4,figsize=(20,4))
wplot1=np.array(wplot)
xplot=stepPlot*(np.arange(np.int(T/stepPlot))+1); xplot=xplot[:len(wplot)]
ax[0].scatter(wplot1[:,0],wplot1[:,1],s=10,alpha=0.25)
ax[0].set_xlabel('w1'); ax[0].set_ylabel('w2'); ax[0].set_title('weight training course')
if EarlyStopping: ax[1].vlines(stepErrorMin*stepPlot,np.min(wplot1.flatten()),np.max(wplot1.flatten()),color='red',label='EarlyStopping')
for i in range(N):
    ax[1].scatter(xplot,wplot1[:,i],s=10,label='w%s' % (i+1))
    ax[1].legend(loc='lower right'); ax[1].set_xlabel('learning epochs'); ax[1].set_ylabel('weights'); #ax[1].set_xscale('log'
# plot cost functions
if EarlyStopping: ax[2].vlines(stepErrorMin*stepPlot,np.min(np.array(Mplot).flatten()),np.max(np.array(Mplot).flatten()),color='red',label='EarlyStopping')
ax[2].scatter(xplot,np.array(Gplot),s=10,label='G')
ax[2].scatter(xplot,np.array(Mplot),s=10,label='M')
ax[2].legend(loc='lower right'); ax[2].set_xlabel('learning epochs'); ax[2].set_ylabel('cost functions'); #ax[1].set_xscale('log')
# plot error rate on the training set
if EarlyStopping: ax[3].vlines(stepErrorMin*stepPlot,np.min(np.array(errorTrain).flatten()),np.max(np.array(errorTrain).flatten()),color='red',label='EarlyStopping')
ax[3].scatter(xplot,np.array(errorTrain),s=10,label='Train error')
ax[3].scatter(xplot,np.array(errorTest),s=10,label='Test error')
ax[3].legend(loc='upper right'); ax[3].set_xlabel('learning epochs'); ax[3].set_ylabel('error'); #ax[1].set_xscale('log')
# plt.savefig('figs/CLASS0_WeightTraining_Alpha' + '{}.pdf'.format(alpha), bbox_inches='tight')

# plot evolution of the classification boundary
fig,ax=plt.subplots(1,4,figsize=(20,4))
step=[0,20,int(np.round(wplot1.shape[0]/3))-1,int(np.round(wplot1.shape[0]))-1]
h25=np.log(0.25/(1-0.25)) # activation corresponding to 0.25 probability of t=1
h75=np.log(0.75/(1-0.75))# activation corresponding to 0.75 probability of t=1

for i in range(len(step)):
    size=100
    ax[i].scatter(x[z==1,0],x[z==1,1],s=size,color='red',alpha=0.25,label='+1')
    ax[i].scatter(x[z==0,0],x[z==0,1],s=size,color='blue',alpha=0.25,label='0')
    ax[i].set_xlabel("x1"); ax[i].set_ylabel("x2")
    ax[i].legend(loc='lower right')
    ax[i].axis('equal')
    x1=np.linspace(x[:,0].min(),x[:,0].max(),num=100)
    y0=(-b-wplot1[step[i],0]*x1)/wplot1[step[i],1]    # h=0 activation
    y1=(-b-h25-wplot1[step[i],0]*x1)/wplot1[step[i],1]    # h=+1 activation
    ym1=(-b-h75-wplot1[step[i],0]*x1)/wplot1[step[i],1]   #h=-1 activation
    ax[i].plot(x1,y0,'k'); ax[i].plot(x1,y1,'--b'); ax[i].plot(x1,ym1,'--g');
    ax[i].set_title("training step %s" % (step[i]*stepPlot))
    ax[i].set_xlim(1.5*x1[0],1.5*x1[-1]); ax[i].set_ylim(1.5*x[:,1].min(),1.5*x[:,1].max());
# Out:
# <ipython-input-138-aad06f3ee6ea>:4: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   xplot=stepPlot*(np.arange(np.int(T/stepPlot))+1); xplot=xplot[:len(wplot)]

# %% [markdown]
# ## Learning as inference
#
# In the second part of this exercise we will reproduce the Figures in Chapter 41 of the MacKay book.
#
# Plot the log-likelihood $G(z^\mu|w_i|,x^\mu_i)$ and the log-posterior $M(w_i|z^\mu,x^\mu_i)$ as functions of the weights, for fixed training data $(z^\mu,x^\mu_i)$

# %%
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter, LogLocator

# size of the training set
ntrain=500
indtrain=np.concatenate([np.arange(ntrain),np.arange(ntrain)+p1])
xplot=x[indtrain]
zplot=z[indtrain]
# create a 2d grid of (w1,w2)
Wmax=30
W1vec=np.arange(-Wmax,+Wmax,0.1)
W2vec=np.arange(-Wmax,+Wmax,0.1)
W1,W2=np.meshgrid(W1vec,W2vec)
len1,len2=W1.shape
Ginference=np.zeros((len1,len2))# log-likelihood
Minference=np.zeros((len1,len2))# log-posterior
Priorinference=np.zeros((len1,len2))# log-prior

for i1 in range(len1):
          for i2 in range(len2):
                  wtemp=np.array([W1[i1,i2],W2[i1,i2]])
                  Ginference[i1,i2]=-Gfunc(wtemp,xplot,zplot)
                  Priorinference[i1,i2]=-0.5*alpha*wtemp.dot(wtemp)
                  Minference[i1,i2]=Ginference[i1,i2]+Priorinference[i1,i2]

# MAP estimate of the weights
wmapind=np.where(Minference==Minference.max())
print('w_MAP: w1=%s, w2=%s' % (W1[wmapind],W2[wmapind]))
# Out:
# <ipython-input-136-c019f941e604>:14: RuntimeWarning: divide by zero encountered in log
#   infhhm=~np.isinf(np.log(1-ff))
# w_MAP: w1=[2.1], w2=[2.4]

# %%
#=========
# PLOTS
#=========
# plot the surface
fig,ax=plt.subplots(1,4,figsize=(20,5))

# weight trajectory from the training cell
wplot1=np.array(wplot)
# rangeplot=stepPlot*(np.arange(np.int(T/stepPlot))+1); rangeplot=rangeplot[:len(wplot)]

# training set
size=100
# scatterplot
ax[0].scatter(xplot[0:ntrain,0],xplot[0:ntrain,1],s=size,color='red',alpha=0.25,label='+1')
ax[0].scatter(xplot[ntrain:2*ntrain,0],xplot[ntrain:2*ntrain,1],s=size,color='blue',alpha=0.25,label='0')
ax[0].set_xlabel("x1"); ax[0].set_ylabel("x2"); ax[0].set_title("training set")
ax[0].legend(loc='lower right')
ax[0].axis('equal')

# plot log-likelihood
surf1=ax[1].imshow(Ginference,origin='lower',cmap='RdGy',extent=[np.min(W1),np.max(W1),np.min(W2),np.max(W2)])
ax[1].contour(W1,W2,Ginference,cmap='RdGy')
fig.colorbar(surf1,ax=ax[1])
ax[1].set_title('log-likelihood'); ax[1].set_xlabel('w1'); ax[1].set_ylabel('w2')
ax[1].scatter(W1[wmapind],W2[wmapind],color='g')

# plot log-prior
surf3=ax[2].imshow(Priorinference,origin='lower',cmap='RdGy',extent=[np.min(W1),np.max(W1),np.min(W2),np.max(W2)])
ax[2].contour(W1,W2,Priorinference,cmap='RdGy')
fig.colorbar(surf3,ax=ax[2])
ax[2].set_title('log-prior'); ax[2].set_xlabel('w1'); ax[2].set_ylabel('w2')
ax[2].scatter(W1[wmapind],W2[wmapind],color='g')

# plot log-posterior
surf2=ax[3].imshow(Minference,origin='lower',cmap='RdGy',extent=[np.min(W1),np.max(W1),np.min(W2),np.max(W2)])
ax[3].contour(W1,W2,Minference,cmap='RdGy')
fig.colorbar(surf2,ax=ax[2])
ax[3].set_title('log-posterior'); ax[3].set_xlabel('w1'); ax[2].set_ylabel('w2')
ax[3].scatter(W1[wmapind],W2[wmapind],color='g')
ax[3].scatter(wplot1[:,0],wplot1[:,1],s=10,alpha=0.25)
ax[3].set_xlabel('w1'); ax[0].set_ylabel('w2'); 
# ax[3].set_title('weight training course')
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>
